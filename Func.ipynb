# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
x = np.linspace(0, 5, 10)
y = x ** 2

# %%
plt.figure()
plt.plot(x, y, 'r')
plt.xlabel('x')
plt.ylabel('y')
plt.title('Essa é uma função quadratica')
plt.show()

# %%
plt.figure()
plt.plot(x+2, y+5, 'r')
plt.xlabel('x')
plt.ylabel('y')
plt.title('Essa é uma função quadratica')
plt.show()

# %%
plt.figure()
plt.plot(y, x, 'r')
plt.xlabel('x')
plt.ylabel('y')
plt.title('Essa é uma função quadratica')
plt.show()
